# %%
import numpy as np
import pandas as pd
import geopandas as gpd
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# import geoplot as gplt
# import geoplot.crs as gcrs

df = pd.read_csv('fused.csv')

italy = gpd.read_file('italy/gadm36_ITA_2.shp')
italy.plot(figsize=(12, 12))

germany = gpd.read_file('germany/gadm36_DEU_2.shp')
germany.plot(figsize=(12, 12))

# %%
italy['NAME_2']
# Out:
# 0        Chieti
# 1      L'Aquila
# 2       Pescara
# 3        Teramo
# 4          Bari
#          ...
# 105      Rovigo
# 106     Treviso
# 107     Venezia
# 108      Verona
# 109     Vicenza
# Name: NAME_2, Length: 110, dtype: object

# %%
df.loc[df['Country/Region'] == 'Italy']['Province/State']
# Out:
# 881      Chieti
# 882    L'Aquila
# 883     Pescara
# 884      Teramo
# 885      Matera
#          ...
# 983      Rovigo
# 984     Treviso
# 985     Venezia
# 986      Verona
# 987     Vicenza
# Name: Province/State, Length: 107, dtype: object

# %%
df['geometry'] = None

# %%
for region in italy['NAME_2']:

# %%
df.loc[df['Province/State'] in df.loc[df['Country/Region'] == 'Italy']['Province/State'].to_numpy()]
# Out:
# C:\Users\Lorenz Hehn\Anaconda3\envs\datascience\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-cb3d3861c8f6> in <module>
# ----> 1 df.loc[df['Province/State'] in df.loc[df['Country/Region'] == 'Italy']['Province/State'].to_numpy()]
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1205             # as it will broadcast
#    1206             if other.ndim != 0 and len(self) != len(other):
# -> 1207                 raise ValueError("Lengths must match to compare")
#    1208
#    1209             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare

# %%
for region in italy['NAME_2']:
    if region in df.loc[df['Country/Region'] == 'Italy']['Province/State'].to_numpy():
        df.loc[df['Province/State'] == region].geometry = italy.loc[italy['NAME_2'] == region].geometry.array
    else:
        print(region)

italy.loc[italy['NAME_2'] == region]
# Out:
# C:\Users\Lorenz Hehn\Anaconda3\envs\datascience\lib\site-packages\geopandas\geodataframe.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[geo_column_name] = level
# Reggio Di Calabria
# Forli' - Cesena
# Reggio Nell'Emilia
# Mantua
# Monza and Brianza
# Pesaro E Urbino
# Carbonia-Iglesias
# Medio Campidano
# Ogliastra
# Olbia-Tempio
# Syracuse
# Florence
# Padua
#     GID_0 NAME_0     GID_1  NAME_1 NL_NAME_1       GID_2   NAME_2 VARNAME_2  \
# 109   ITA  Italy  ITA.20_1  Veneto      None  ITA.20.7_1  Vicenza   Vicence
#
#     NL_NAME_2     TYPE_2 ENGTYPE_2 CC_2 HASC_2  \
# 109      None  Provincia  Province   24  IT.VI
#
#                                               geometry
# ...

# %%
italy
# Out:
#     GID_0 NAME_0     GID_1   NAME_1 NL_NAME_1       GID_2    NAME_2  \
# 0     ITA  Italy   ITA.1_1  Abruzzo      None   ITA.1.1_1    Chieti
# 1     ITA  Italy   ITA.1_1  Abruzzo      None   ITA.1.2_1  L'Aquila
# 2     ITA  Italy   ITA.1_1  Abruzzo      None   ITA.1.3_1   Pescara
# 3     ITA  Italy   ITA.1_1  Abruzzo      None   ITA.1.4_1    Teramo
# 4     ITA  Italy   ITA.2_1   Apulia      None   ITA.2.1_1      Bari
# ..    ...    ...       ...      ...       ...         ...       ...
# 105   ITA  Italy  ITA.20_1   Veneto      None  ITA.20.3_1    Rovigo
# 106   ITA  Italy  ITA.20_1   Veneto      None  ITA.20.4_1   Treviso
# 107   ITA  Italy  ITA.20_1   Veneto      None  ITA.20.5_1   Venezia
# 108   ITA  Italy  ITA.20_1   Veneto      None  ITA.20.6_1    Verona
# 109   ITA  Italy  ITA.20_1   Veneto      None  ITA.20.7_1   Vicenza
#
#                                   VARNAME_2 NL_NAME_2     TYPE_2 ENGTYPE_2  \
# ...

# %%
gdf = gpd.GeoDataFrame(df)

# %%
gdf
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\envs\datascience\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\Anaconda3\envs\datascience\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     397                         if cls is not object \
#     398                                 and callable(cls.__dict__.get('__repr__')):
# --> 399                             return _repr_pprint(obj, self, cycle)
#     400
#     401             return _default_pprint(obj, self, cycle)
#
# ...
